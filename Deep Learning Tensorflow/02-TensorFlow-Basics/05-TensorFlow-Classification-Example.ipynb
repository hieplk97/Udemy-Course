# %% [markdown]
# # TensorFlow Classification

# %% [markdown]
# ## Data
#
# https://archive.ics.uci.edu/ml/datasets/pima+indians+diabetes
#
# 1. Title: Pima Indians Diabetes Database
#
# 2. Sources:
#    (a) Original owners: National Institute of Diabetes and Digestive and
#                         Kidney Diseases
#    (b) Donor of database: Vincent Sigillito (vgs@aplcen.apl.jhu.edu)
#                           Research Center, RMI Group Leader
#                           Applied Physics Laboratory
#                           The Johns Hopkins University
#                           Johns Hopkins Road
#                           Laurel, MD 20707
#                           (301) 953-6231
#    (c) Date received: 9 May 1990
#
# 3. Past Usage:
#     1. Smith,~J.~W., Everhart,~J.~E., Dickson,~W.~C., Knowler,~W.~C., \&
#        Johannes,~R.~S. (1988). Using the ADAP learning algorithm to forecast
#        the onset of diabetes mellitus.  In {\it Proceedings of the Symposium
#        on Computer Applications and Medical Care} (pp. 261--265).  IEEE
#        Computer Society Press.
#
#        The diagnostic, binary-valued variable investigated is whether the
#        patient shows signs of diabetes according to World Health Organization
#        criteria (i.e., if the 2 hour post-load plasma glucose was at least
#        200 mg/dl at any survey  examination or if found during routine medical
#        care).   The population lives near Phoenix, Arizona, USA.
#
#        Results: Their ADAP algorithm makes a real-valued prediction between
#        0 and 1.  This was transformed into a binary decision using a cutoff of
#        0.448.  Using 576 training instances, the sensitivity and specificity
#        of their algorithm was 76% on the remaining 192 instances.
#
# 4. Relevant Information:
#       Several constraints were placed on the selection of these instances from
#       a larger database.  In particular, all patients here are females at
#       least 21 years old of Pima Indian heritage.  ADAP is an adaptive learning
#       routine that generates and executes digital analogs of perceptron-like
#       devices.  It is a unique algorithm; see the paper for details.
#
# 5. Number of Instances: 768
#
# 6. Number of Attributes: 8 plus class
#
#     7. For Each Attribute: (all numeric-valued)
#        1. Number of times pregnant
#        2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#        3. Diastolic blood pressure (mm Hg)
#        4. Triceps skin fold thickness (mm)
#        5. 2-Hour serum insulin (mu U/ml)
#        6. Body mass index (weight in kg/(height in m)^2)
#        7. Diabetes pedigree function
#        8. Age (years)
#        9. Class variable (0 or 1)
#
# 8. Missing Attribute Values: Yes
#
# 9. Class Distribution: (class value 1 is interpreted as "tested positive for
#    diabetes")
#
#    Class Value  Number of instances
#    0            500
#    1            268
#
# 10. Brief statistical analysis:
#
#         Attribute number:    Mean:   Standard Deviation:
#         1.                     3.8     3.4
#         2.                   120.9    32.0
#         3.                    69.1    19.4
#         4.                    20.5    16.0
#         5.                    79.8   115.2
#         6.                    32.0     7.9
#         7.                     0.5     0.3
#         8.                    33.2    11.8

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %% [markdown]
# ### Clean the Data

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %% [markdown]
# ### Feature Columns

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
import tensorflow as tf

# %% [markdown]
# ### Continuous Features
#
# * Number of times pregnant
# * Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * Diastolic blood pressure (mm Hg)
# * Triceps skin fold thickness (mm)
# * 2-Hour serum insulin (mu U/ml)
# * Body mass index (weight in kg/(height in m)^2)
# * Diabetes pedigree function

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# If you know the set of all possible feature values of a column and there are only a few of them, you can use categorical_column_with_vocabulary_list. If you don't know the set of possible values in advance you can use categorical_column_with_hash_bucket

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])
# Alternative
# assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %% [markdown]
# ### Converting Continuous to Categorical

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
age_buckets = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %% [markdown]
# ### Putting them together

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,assigned_group, age_buckets]

# %% [markdown]
# ### Train Test Split

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Number_pregnant        768 non-null    float64
#  1   Glucose_concentration  768 non-null    float64
#  2   Blood_pressure         768 non-null    float64
#  3   Triceps                768 non-null    float64
#  4   Insulin                768 non-null    float64
#  5   BMI                    768 non-null    float64
#  6   Pedigree               768 non-null    float64
#  7   Age                    768 non-null    int64
#  8   Class                  768 non-null    int64
#  9   Group                  768 non-null    object
# dtypes: float64(7), int64(2), object(1)
# memory usage: 60.1+ KB

# %%
x_data = diabetes.drop('Class',axis=1)

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.33, random_state=101)

# %% [markdown]
# ### Input Function

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %% [markdown]
# ### Creating the Model

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\sgvn252\AppData\Local\Temp\tmpv8bmh4cj
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\sgvn252\\AppData\\Local\\Temp\\tmpv8bmh4cj', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000015C48B50DA0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# WARNING:tensorflow:From c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_core\python\feature_column\feature_column_v2.py:305: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_core\python\ops\embedding_ops.py:802: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_estimator\python\estimator\canned\linear.py:308: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_core\python\training\monitored_session.py:882: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\sgvn252\AppData\Local\Temp\tmpv8bmh4cj\model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 285.628
# INFO:tensorflow:loss = 6.464576, step = 101 (0.351 sec)
# INFO:tensorflow:global_step/sec: 671.959
# INFO:tensorflow:loss = 5.544735, step = 201 (0.147 sec)
# INFO:tensorflow:global_step/sec: 673.065
# INFO:tensorflow:loss = 6.3544645, step = 301 (0.149 sec)
# INFO:tensorflow:global_step/sec: 606.42
# INFO:tensorflow:loss = 6.585674, step = 401 (0.165 sec)
# INFO:tensorflow:global_step/sec: 600.069
# INFO:tensorflow:loss = 5.4043894, step = 501 (0.167 sec)
# INFO:tensorflow:global_step/sec: 548.134
# INFO:tensorflow:loss = 5.2032037, step = 601 (0.182 sec)
# INFO:tensorflow:global_step/sec: 646.956
# INFO:tensorflow:loss = 5.764847, step = 701 (0.155 sec)
# INFO:tensorflow:global_step/sec: 551.876
# INFO:tensorflow:loss = 4.964383, step = 801 (0.181 sec)
# INFO:tensorflow:global_step/sec: 663.359
# INFO:tensorflow:loss = 5.5192733, step = 901 (0.166 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\sgvn252\AppData\Local\Temp\tmpv8bmh4cj\model.ckpt.
# INFO:tensorflow:Loss for final step: 4.8464503.

# %%
# Useful link ofr your own data
# https://stackoverflow.com/questions/44664285/what-are-the-contraints-for-tensorflow-scope-names

# %% [markdown]
# ## Evaluation

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_core\python\ops\metrics_impl.py:2026: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-11-05T16:24:55Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\sgvn252\AppData\Local\Temp\tmpv8bmh4cj\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-11-05-16:24:56
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.7322835, accuracy_baseline = 0.65748036, auc = 0.7812995, auc_precision_recall = 0.6184639, average_loss = 0.5356252, global_step = 1000, label/mean = 0.34251967, loss = 5.2326465, precision = 0.6233766, prediction/mean = 0.36344072, recall = 0.55172414
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\sgvn252\AppData\Local\Temp\tmpv8bmh4cj\model.ckpt-1000

# %%
results
# Out:
# {'accuracy': 0.7322835,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.7812995,
#  'auc_precision_recall': 0.6184639,
#  'average_loss': 0.5356252,
#  'label/mean': 0.34251967,
#  'loss': 5.2326465,
#  'precision': 0.6233766,
#  'prediction/mean': 0.36344072,
#  'recall': 0.55172414,
#  'global_step': 1000}

# %% [markdown]
# ## Predictions

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
# Predictions is a generator! 
predictions = model.predict(pred_input_func)

# %%
list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\sgvn252\AppData\Local\Temp\tmpv8bmh4cj\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'logits': array([0.12802291], dtype=float32),
#   'logistic': array([0.5319621], dtype=float32),
#   'probabilities': array([0.46803793, 0.5319621 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4496299], dtype=float32),
#   'logistic': array([0.61055124], dtype=float32),
#   'probabilities': array([0.38944876, 0.61055124], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.45354146], dtype=float32),
#   'logistic': array([0.3885191], dtype=float32),
#   'probabilities': array([0.6114809 , 0.38851908], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.775041], dtype=float32),
#   'logistic': array([0.31538966], dtype=float32),
#   'probabilities': array([0.68461037, 0.31538966], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7746394], dtype=float32),
#   'logistic': array([0.14496633], dtype=float32),
#   'probabilities': array([0.8550337 , 0.14496633], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.6419306], dtype=float32),
#   'logistic': array([0.6551897], dtype=float32),
#   'probabilities': array([0.34481025, 0.65518975], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.31703103], dtype=float32),
#   'logistic': array([0.5786005], dtype=float32),
#   'probabilities': array([0.4213995, 0.5786005], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.56430376], dtype=float32),
#   'logistic': array([0.36255226], dtype=float32),
#   'probabilities': array([0.6374478 , 0.36255223], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1823393], dtype=float32),
#   'logistic': array([0.23463184], dtype=float32),
#   'probabilities': array([0.76536816, 0.23463184], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0918736], dtype=float32),
#   'logistic': array([0.25126562], dtype=float32),
#   'probabilities': array([0.74873435, 0.25126562], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9293238], dtype=float32),
#   'logistic': array([0.12682548], dtype=float32),
#   'probabilities': array([0.87317455, 0.12682545], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.736569], dtype=float32),
#   'logistic': array([0.14974922], dtype=float32),
#   'probabilities': array([0.8502508 , 0.14974926], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.86025774], dtype=float32),
#   'logistic': array([0.2972855], dtype=float32),
#   'probabilities': array([0.7027145, 0.2972855], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.30879104], dtype=float32),
#   'logistic': array([0.5765901], dtype=float32),
#   'probabilities': array([0.42340985, 0.5765901 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6226122], dtype=float32),
#   'logistic': array([0.1648449], dtype=float32),
#   'probabilities': array([0.83515507, 0.16484493], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.81622636], dtype=float32),
#   'logistic': array([0.30656528], dtype=float32),
#   'probabilities': array([0.6934347 , 0.30656528], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.61511934], dtype=float32),
#   'logistic': array([0.3508923], dtype=float32),
#   'probabilities': array([0.6491077, 0.3508923], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.937887], dtype=float32),
#   'logistic': array([0.12588021], dtype=float32),
#   'probabilities': array([0.8741198 , 0.12588018], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5817406], dtype=float32),
#   'logistic': array([0.35853216], dtype=float32),
#   'probabilities': array([0.6414678, 0.3585322], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8241735], dtype=float32),
#   'logistic': array([0.13893385], dtype=float32),
#   'probabilities': array([0.86106616, 0.13893384], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3248856], dtype=float32),
#   'logistic': array([0.2100066], dtype=float32),
#   'probabilities': array([0.7899934 , 0.21000661], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.912956], dtype=float32),
#   'logistic': array([0.2863953], dtype=float32),
#   'probabilities': array([0.7136046, 0.2863953], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.6639396], dtype=float32),
#   'logistic': array([0.6601448], dtype=float32),
#   'probabilities': array([0.3398552, 0.6601448], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3462541], dtype=float32),
#   'logistic': array([0.20648345], dtype=float32),
#   'probabilities': array([0.7935166 , 0.20648347], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.584475], dtype=float32),
#   'logistic': array([0.17016265], dtype=float32),
#   'probabilities': array([0.8298373 , 0.17016263], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1027274], dtype=float32),
#   'logistic': array([0.7507708], dtype=float32),
#   'probabilities': array([0.2492292 , 0.75077075], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5347025], dtype=float32),
#   'logistic': array([0.17730668], dtype=float32),
#   'probabilities': array([0.8226933 , 0.17730668], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.87896526], dtype=float32),
#   'logistic': array([0.29339227], dtype=float32),
#   'probabilities': array([0.7066077 , 0.29339224], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1831713], dtype=float32),
#   'logistic': array([0.10127193], dtype=float32),
#   'probabilities': array([0.898728  , 0.10127192], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.35183668], dtype=float32),
#   'logistic': array([0.5870629], dtype=float32),
#   'probabilities': array([0.4129371, 0.5870629], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.6648288], dtype=float32),
#   'logistic': array([0.9349191], dtype=float32),
#   'probabilities': array([0.0650809 , 0.93491906], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.37445748], dtype=float32),
#   'logistic': array([0.40746439], dtype=float32),
#   'probabilities': array([0.5925356 , 0.40746439], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.83355796], dtype=float32),
#   'logistic': array([0.30289328], dtype=float32),
#   'probabilities': array([0.6971067 , 0.30289328], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2593472], dtype=float32),
#   'logistic': array([0.5644758], dtype=float32),
#   'probabilities': array([0.4355242 , 0.56447583], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2024409], dtype=float32),
#   'logistic': array([0.23104131], dtype=float32),
#   'probabilities': array([0.76895875, 0.23104128], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.47294575], dtype=float32),
#   'logistic': array([0.38391927], dtype=float32),
#   'probabilities': array([0.6160807 , 0.38391924], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.05508208], dtype=float32),
#   'logistic': array([0.51376706], dtype=float32),
#   'probabilities': array([0.48623297, 0.51376706], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5308595], dtype=float32),
#   'logistic': array([0.62968355], dtype=float32),
#   'probabilities': array([0.37031645, 0.62968355], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.0703454], dtype=float32),
#   'logistic': array([0.74466264], dtype=float32),
#   'probabilities': array([0.25533742, 0.74466264], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.67303896], dtype=float32),
#   'logistic': array([0.33781672], dtype=float32),
#   'probabilities': array([0.6621833, 0.3378167], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.524715], dtype=float32),
#   'logistic': array([0.17876825], dtype=float32),
#   'probabilities': array([0.8212317 , 0.17876828], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.14413953], dtype=float32),
#   'logistic': array([0.5359726], dtype=float32),
#   'probabilities': array([0.46402735, 0.5359726 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7734356], dtype=float32),
#   'logistic': array([0.14511558], dtype=float32),
#   'probabilities': array([0.8548844, 0.1451156], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.09020412], dtype=float32),
#   'logistic': array([0.52253574], dtype=float32),
#   'probabilities': array([0.47746423, 0.52253574], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8509182], dtype=float32),
#   'logistic': array([0.1357651], dtype=float32),
#   'probabilities': array([0.8642349 , 0.13576515], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1217585], dtype=float32),
#   'logistic': array([0.1069999], dtype=float32),
#   'probabilities': array([0.89300007, 0.10699993], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.43209386], dtype=float32),
#   'logistic': array([0.60637355], dtype=float32),
#   'probabilities': array([0.39362645, 0.60637355], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5083727], dtype=float32),
#   'logistic': array([0.18118009], dtype=float32),
#   'probabilities': array([0.81881994, 0.18118009], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4372795], dtype=float32),
#   'logistic': array([0.19196698], dtype=float32),
#   'probabilities': array([0.80803305, 0.191967  ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0423138], dtype=float32),
#   'logistic': array([0.11483134], dtype=float32),
#   'probabilities': array([0.8851687 , 0.11483134], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6118202], dtype=float32),
#   'logistic': array([0.16633606], dtype=float32),
#   'probabilities': array([0.8336639 , 0.16633604], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.171269], dtype=float32),
#   'logistic': array([0.2366257], dtype=float32),
#   'probabilities': array([0.7633743 , 0.23662569], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1147468], dtype=float32),
#   'logistic': array([0.24698702], dtype=float32),
#   'probabilities': array([0.753013, 0.246987], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.49831116], dtype=float32),
#   'logistic': array([0.37793764], dtype=float32),
#   'probabilities': array([0.6220624 , 0.37793764], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9068375], dtype=float32),
#   'logistic': array([0.12933654], dtype=float32),
#   'probabilities': array([0.87066346, 0.12933657], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3062882], dtype=float32),
#   'logistic': array([0.21310863], dtype=float32),
#   'probabilities': array([0.78689134, 0.2131086 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3601863], dtype=float32),
#   'logistic': array([0.20421001], dtype=float32),
#   'probabilities': array([0.79578996, 0.20421001], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3429856], dtype=float32),
#   'logistic': array([0.20701954], dtype=float32),
#   'probabilities': array([0.79298055, 0.20701952], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.06326652], dtype=float32),
#   'logistic': array([0.48418865], dtype=float32),
#   'probabilities': array([0.5158113 , 0.48418862], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6391044], dtype=float32),
#   'logistic': array([0.16258696], dtype=float32),
#   'probabilities': array([0.837413  , 0.16258697], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2170262], dtype=float32),
#   'logistic': array([0.22846022], dtype=float32),
#   'probabilities': array([0.7715398, 0.2284602], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5756639], dtype=float32),
#   'logistic': array([0.64006907], dtype=float32),
#   'probabilities': array([0.35993093, 0.64006907], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.48890865], dtype=float32),
#   'logistic': array([0.61984926], dtype=float32),
#   'probabilities': array([0.38015074, 0.6198493 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.06710279], dtype=float32),
#   'logistic': array([0.5167694], dtype=float32),
#   'probabilities': array([0.4832306, 0.5167694], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.662092], dtype=float32),
#   'logistic': array([0.34026983], dtype=float32),
#   'probabilities': array([0.6597302 , 0.34026983], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.10914278], dtype=float32),
#   'logistic': array([0.47274137], dtype=float32),
#   'probabilities': array([0.52725863, 0.47274137], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5515286], dtype=float32),
#   'logistic': array([0.17486563], dtype=float32),
#   'probabilities': array([0.82513434, 0.17486559], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.445312], dtype=float32),
#   'logistic': array([0.19072407], dtype=float32),
#   'probabilities': array([0.8092759, 0.1907241], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7285109], dtype=float32),
#   'logistic': array([0.15077816], dtype=float32),
#   'probabilities': array([0.8492218 , 0.15077814], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9349486], dtype=float32),
#   'logistic': array([0.12620386], dtype=float32),
#   'probabilities': array([0.8737961 , 0.12620385], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.35276937], dtype=float32),
#   'logistic': array([0.587289], dtype=float32),
#   'probabilities': array([0.412711, 0.587289], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2569501], dtype=float32),
#   'logistic': array([0.22149935], dtype=float32),
#   'probabilities': array([0.7785007 , 0.22149935], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.27495676], dtype=float32),
#   'logistic': array([0.43169063], dtype=float32),
#   'probabilities': array([0.56830937, 0.4316906 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.33367825], dtype=float32),
#   'logistic': array([0.58265406], dtype=float32),
#   'probabilities': array([0.4173459 , 0.58265406], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.96274984], dtype=float32),
#   'logistic': array([0.27632797], dtype=float32),
#   'probabilities': array([0.72367203, 0.27632797], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5228648], dtype=float32),
#   'logistic': array([0.6278174], dtype=float32),
#   'probabilities': array([0.37218258, 0.6278174 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9428489], dtype=float32),
#   'logistic': array([0.12533519], dtype=float32),
#   'probabilities': array([0.8746648 , 0.12533522], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.34840953], dtype=float32),
#   'logistic': array([0.5862318], dtype=float32),
#   'probabilities': array([0.41376814, 0.5862318 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9632258], dtype=float32),
#   'logistic': array([0.12311837], dtype=float32),
#   'probabilities': array([0.87688166, 0.12311836], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.18728781], dtype=float32),
#   'logistic': array([0.5466856], dtype=float32),
#   'probabilities': array([0.45331442, 0.5466856 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7933543], dtype=float32),
#   'logistic': array([0.3114489], dtype=float32),
#   'probabilities': array([0.6885511, 0.3114489], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6656594], dtype=float32),
#   'logistic': array([0.15900376], dtype=float32),
#   'probabilities': array([0.84099627, 0.15900375], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2273767], dtype=float32),
#   'logistic': array([0.5566005], dtype=float32),
#   'probabilities': array([0.44339943, 0.5566005 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.34603345], dtype=float32),
#   'logistic': array([0.58565533], dtype=float32),
#   'probabilities': array([0.4143446, 0.5856554], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.11881089], dtype=float32),
#   'logistic': array([0.52966785], dtype=float32),
#   'probabilities': array([0.47033218, 0.52966785], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6242082], dtype=float32),
#   'logistic': array([0.16462535], dtype=float32),
#   'probabilities': array([0.8353747 , 0.16462533], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6622193], dtype=float32),
#   'logistic': array([0.34024125], dtype=float32),
#   'probabilities': array([0.65975875, 0.34024128], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7772311], dtype=float32),
#   'logistic': array([0.14464536], dtype=float32),
#   'probabilities': array([0.8553546 , 0.14464538], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.8286104], dtype=float32),
#   'logistic': array([0.696061], dtype=float32),
#   'probabilities': array([0.30393896, 0.696061  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.4133897], dtype=float32),
#   'logistic': array([0.8043], dtype=float32),
#   'probabilities': array([0.19569996, 0.8043    ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4772079], dtype=float32),
#   'logistic': array([0.6170883], dtype=float32),
#   'probabilities': array([0.38291168, 0.6170884 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3611116], dtype=float32),
#   'logistic': array([0.20405969], dtype=float32),
#   'probabilities': array([0.79594034, 0.20405969], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.2802962], dtype=float32),
#   'logistic': array([0.43038118], dtype=float32),
#   'probabilities': array([0.5696188 , 0.43038115], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5008917], dtype=float32),
#   'logistic': array([0.37733114], dtype=float32),
#   'probabilities': array([0.62266886, 0.37733114], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.14666641], dtype=float32),
#   'logistic': array([0.463399], dtype=float32),
#   'probabilities': array([0.536601, 0.463399], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6405449], dtype=float32),
#   'logistic': array([0.34512338], dtype=float32),
#   'probabilities': array([0.6548766 , 0.34512335], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.16244704], dtype=float32),
#   'logistic': array([0.4594773], dtype=float32),
#   'probabilities': array([0.5405227 , 0.45947734], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.729154], dtype=float32),
#   'logistic': array([0.15069583], dtype=float32),
#   'probabilities': array([0.8493042 , 0.15069583], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.20562601], dtype=float32),
#   'logistic': array([0.55122614], dtype=float32),
#   'probabilities': array([0.4487739 , 0.55122614], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.20384431], dtype=float32),
#   'logistic': array([0.5507853], dtype=float32),
#   'probabilities': array([0.44921464, 0.5507853 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2131355], dtype=float32),
#   'logistic': array([0.22914675], dtype=float32),
#   'probabilities': array([0.7708533 , 0.22914673], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5757456], dtype=float32),
#   'logistic': array([0.17139885], dtype=float32),
#   'probabilities': array([0.8286011 , 0.17139885], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5848427], dtype=float32),
#   'logistic': array([0.17011073], dtype=float32),
#   'probabilities': array([0.8298893 , 0.17011075], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9931511], dtype=float32),
#   'logistic': array([0.27029014], dtype=float32),
#   'probabilities': array([0.7297099 , 0.27029014], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.46551722], dtype=float32),
#   'logistic': array([0.3856778], dtype=float32),
#   'probabilities': array([0.61432225, 0.38567784], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8753388], dtype=float32),
#   'logistic': array([0.13292518], dtype=float32),
#   'probabilities': array([0.8670748 , 0.13292518], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.72726274], dtype=float32),
#   'logistic': array([0.3257957], dtype=float32),
#   'probabilities': array([0.67420435, 0.3257957 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1977711], dtype=float32),
#   'logistic': array([0.23187196], dtype=float32),
#   'probabilities': array([0.76812804, 0.23187196], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.244497], dtype=float32),
#   'logistic': array([0.0958252], dtype=float32),
#   'probabilities': array([0.90417475, 0.09582519], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9747665], dtype=float32),
#   'logistic': array([0.12187784], dtype=float32),
#   'probabilities': array([0.87812215, 0.12187784], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.0432506], dtype=float32),
#   'logistic': array([0.7394767], dtype=float32),
#   'probabilities': array([0.2605233 , 0.73947674], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5407239], dtype=float32),
#   'logistic': array([0.17643008], dtype=float32),
#   'probabilities': array([0.8235699 , 0.17643005], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.919527], dtype=float32),
#   'logistic': array([0.12791428], dtype=float32),
#   'probabilities': array([0.8720857 , 0.12791432], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8312716], dtype=float32),
#   'logistic': array([0.13808683], dtype=float32),
#   'probabilities': array([0.8619132 , 0.13808687], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.09809291], dtype=float32),
#   'logistic': array([0.4754964], dtype=float32),
#   'probabilities': array([0.5245036, 0.4754964], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.18693095], dtype=float32),
#   'logistic': array([0.45340288], dtype=float32),
#   'probabilities': array([0.5465971 , 0.45340288], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1851784], dtype=float32),
#   'logistic': array([0.2341224], dtype=float32),
#   'probabilities': array([0.76587766, 0.2341224 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.25309914], dtype=float32),
#   'logistic': array([0.43706086], dtype=float32),
#   'probabilities': array([0.56293917, 0.43706086], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.541274], dtype=float32),
#   'logistic': array([0.17635016], dtype=float32),
#   'probabilities': array([0.8236498 , 0.17635016], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2637157], dtype=float32),
#   'logistic': array([0.2203349], dtype=float32),
#   'probabilities': array([0.7796651, 0.2203349], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.08811116], dtype=float32),
#   'logistic': array([0.47798645], dtype=float32),
#   'probabilities': array([0.52201355, 0.47798643], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.11334264], dtype=float32),
#   'logistic': array([0.47169465], dtype=float32),
#   'probabilities': array([0.52830535, 0.47169462], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8549252], dtype=float32),
#   'logistic': array([0.13529566], dtype=float32),
#   'probabilities': array([0.8647043 , 0.13529566], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.43827754], dtype=float32),
#   'logistic': array([0.39215147], dtype=float32),
#   'probabilities': array([0.6078485 , 0.39215147], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.7543584], dtype=float32),
#   'logistic': array([0.6801276], dtype=float32),
#   'probabilities': array([0.31987235, 0.6801276 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.12410569], dtype=float32),
#   'logistic': array([0.53098667], dtype=float32),
#   'probabilities': array([0.46901333, 0.53098667], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.4503178], dtype=float32),
#   'logistic': array([0.3892852], dtype=float32),
#   'probabilities': array([0.6107148, 0.3892852], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.12070739], dtype=float32),
#   'logistic': array([0.5301403], dtype=float32),
#   'probabilities': array([0.46985975, 0.5301403 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2201337], dtype=float32),
#   'logistic': array([0.22791293], dtype=float32),
#   'probabilities': array([0.7720871 , 0.22791295], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4715166], dtype=float32),
#   'logistic': array([0.1867122], dtype=float32),
#   'probabilities': array([0.8132878, 0.1867122], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9120504], dtype=float32),
#   'logistic': array([0.12875071], dtype=float32),
#   'probabilities': array([0.8712493 , 0.12875068], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.124805], dtype=float32),
#   'logistic': array([0.24512109], dtype=float32),
#   'probabilities': array([0.7548789 , 0.24512109], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.10027105], dtype=float32),
#   'logistic': array([0.47495323], dtype=float32),
#   'probabilities': array([0.52504677, 0.4749532 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.7190583], dtype=float32),
#   'logistic': array([0.6723996], dtype=float32),
#   'probabilities': array([0.3276004, 0.6723996], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2674031], dtype=float32),
#   'logistic': array([0.21970215], dtype=float32),
#   'probabilities': array([0.7802979 , 0.21970211], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7077088], dtype=float32),
#   'logistic': array([0.15346113], dtype=float32),
#   'probabilities': array([0.8465389 , 0.15346113], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.33490252], dtype=float32),
#   'logistic': array([0.41704825], dtype=float32),
#   'probabilities': array([0.5829517 , 0.41704825], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2454739], dtype=float32),
#   'logistic': array([0.22348464], dtype=float32),
#   'probabilities': array([0.77651536, 0.2234846 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7821432], dtype=float32),
#   'logistic': array([0.14403869], dtype=float32),
#   'probabilities': array([0.85596126, 0.14403868], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.514586], dtype=float32),
#   'logistic': array([0.18026015], dtype=float32),
#   'probabilities': array([0.8197399 , 0.18026015], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9695729], dtype=float32),
#   'logistic': array([0.12243474], dtype=float32),
#   'probabilities': array([0.8775652 , 0.12243477], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5563038], dtype=float32),
#   'logistic': array([0.36440313], dtype=float32),
#   'probabilities': array([0.63559693, 0.36440313], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1775324], dtype=float32),
#   'logistic': array([0.76450384], dtype=float32),
#   'probabilities': array([0.23549616, 0.76450384], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
# ...
#  {'logits': array([0.75669336], dtype=float32),
#   'logistic': array([0.6806354], dtype=float32),
#   'probabilities': array([0.3193646, 0.6806354], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4383936], dtype=float32),
#   'logistic': array([0.6078762], dtype=float32),
#   'probabilities': array([0.39212382, 0.6078762 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.8199383], dtype=float32),
#   'logistic': array([0.6942233], dtype=float32),
#   'probabilities': array([0.30577677, 0.6942233 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.2075572], dtype=float32),
#   'logistic': array([0.4482962], dtype=float32),
#   'probabilities': array([0.5517038, 0.4482962], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.871248], dtype=float32),
#   'logistic': array([0.2949947], dtype=float32),
#   'probabilities': array([0.7050053 , 0.29499468], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.03302002], dtype=float32),
#   'logistic': array([0.50825423], dtype=float32),
#   'probabilities': array([0.49174577, 0.5082543 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5705624], dtype=float32),
#   'logistic': array([0.17213625], dtype=float32),
#   'probabilities': array([0.8278638 , 0.17213625], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8000962], dtype=float32),
#   'logistic': array([0.14183936], dtype=float32),
#   'probabilities': array([0.8581607 , 0.14183937], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5320237], dtype=float32),
#   'logistic': array([0.17769775], dtype=float32),
#   'probabilities': array([0.82230216, 0.1776978 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.00472975], dtype=float32),
#   'logistic': array([0.49881756], dtype=float32),
#   'probabilities': array([0.50118244, 0.49881756], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.683291], dtype=float32),
#   'logistic': array([0.06396654], dtype=float32),
#   'probabilities': array([0.9360334 , 0.06396655], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.99359983], dtype=float32),
#   'logistic': array([0.27020162], dtype=float32),
#   'probabilities': array([0.72979844, 0.27020165], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6379619], dtype=float32),
#   'logistic': array([0.16274258], dtype=float32),
#   'probabilities': array([0.83725744, 0.16274258], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.97255915], dtype=float32),
#   'logistic': array([0.2743707], dtype=float32),
#   'probabilities': array([0.7256293, 0.2743707], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2118188], dtype=float32),
#   'logistic': array([0.22937939], dtype=float32),
#   'probabilities': array([0.77062064, 0.2293794 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0404446], dtype=float32),
#   'logistic': array([0.26106423], dtype=float32),
#   'probabilities': array([0.73893577, 0.2610642 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1683364], dtype=float32),
#   'logistic': array([0.7628442], dtype=float32),
#   'probabilities': array([0.23715581, 0.76284415], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5981169], dtype=float32),
#   'logistic': array([0.16824502], dtype=float32),
#   'probabilities': array([0.83175504, 0.16824497], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.003284], dtype=float32),
#   'logistic': array([0.11885852], dtype=float32),
#   'probabilities': array([0.8811415 , 0.11885856], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.32324898], dtype=float32),
#   'logistic': array([0.58011585], dtype=float32),
#   'probabilities': array([0.41988415, 0.58011585], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.10637158], dtype=float32),
#   'logistic': array([0.47343215], dtype=float32),
#   'probabilities': array([0.5265678 , 0.47343212], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.6797724], dtype=float32),
#   'logistic': array([0.8428744], dtype=float32),
#   'probabilities': array([0.15712562, 0.8428744 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.53973305], dtype=float32),
#   'logistic': array([0.6317503], dtype=float32),
#   'probabilities': array([0.36824968, 0.6317503 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9792154], dtype=float32),
#   'logistic': array([0.1214025], dtype=float32),
#   'probabilities': array([0.8785975 , 0.12140251], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5664213], dtype=float32),
#   'logistic': array([0.63793695], dtype=float32),
#   'probabilities': array([0.36206302, 0.637937  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.1499598], dtype=float32),
#   'logistic': array([0.53741986], dtype=float32),
#   'probabilities': array([0.46258014, 0.53741986], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1343751], dtype=float32),
#   'logistic': array([0.7566454], dtype=float32),
#   'probabilities': array([0.24335457, 0.7566454 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2587359], dtype=float32),
#   'logistic': array([0.22119159], dtype=float32),
#   'probabilities': array([0.7788084 , 0.22119157], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.629581], dtype=float32),
#   'logistic': array([0.16388777], dtype=float32),
#   'probabilities': array([0.83611226, 0.16388778], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.16791642], dtype=float32),
#   'logistic': array([0.5418807], dtype=float32),
#   'probabilities': array([0.45811927, 0.5418808 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.744404], dtype=float32),
#   'logistic': array([0.14875442], dtype=float32),
#   'probabilities': array([0.8512456 , 0.14875442], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2152495], dtype=float32),
#   'logistic': array([0.77122647], dtype=float32),
#   'probabilities': array([0.22877352, 0.77122647], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.03029954], dtype=float32),
#   'logistic': array([0.5075743], dtype=float32),
#   'probabilities': array([0.4924257, 0.5075743], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6099042], dtype=float32),
#   'logistic': array([0.16660193], dtype=float32),
#   'probabilities': array([0.83339804, 0.16660191], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.20020854], dtype=float32),
#   'logistic': array([0.54988563], dtype=float32),
#   'probabilities': array([0.45011437, 0.54988563], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.1404447], dtype=float32),
#   'logistic': array([0.46494642], dtype=float32),
#   'probabilities': array([0.53505355, 0.4649464 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0788145], dtype=float32),
#   'logistic': array([0.111173], dtype=float32),
#   'probabilities': array([0.8888269 , 0.11117306], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.05899644], dtype=float32),
#   'logistic': array([0.5147448], dtype=float32),
#   'probabilities': array([0.48525515, 0.5147448 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.36074865], dtype=float32),
#   'logistic': array([0.58922166], dtype=float32),
#   'probabilities': array([0.4107783, 0.5892216], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.98460126], dtype=float32),
#   'logistic': array([0.72802025], dtype=float32),
#   'probabilities': array([0.27197975, 0.7280203 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.3681746], dtype=float32),
#   'logistic': array([0.79708505], dtype=float32),
#   'probabilities': array([0.20291494, 0.7970851 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.27788556], dtype=float32),
#   'logistic': array([0.43097225], dtype=float32),
#   'probabilities': array([0.5690278 , 0.43097222], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6786573], dtype=float32),
#   'logistic': array([0.15727335], dtype=float32),
#   'probabilities': array([0.84272665, 0.15727335], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.3698163], dtype=float32),
#   'logistic': array([0.0855035], dtype=float32),
#   'probabilities': array([0.91449654, 0.08550351], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1455526], dtype=float32),
#   'logistic': array([0.10474754], dtype=float32),
#   'probabilities': array([0.89525247, 0.10474755], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0956341], dtype=float32),
#   'logistic': array([0.25055882], dtype=float32),
#   'probabilities': array([0.74944115, 0.25055882], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.73372525], dtype=float32),
#   'logistic': array([0.32437778], dtype=float32),
#   'probabilities': array([0.6756222 , 0.32437778], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0776345], dtype=float32),
#   'logistic': array([0.25395393], dtype=float32),
#   'probabilities': array([0.7460461 , 0.25395396], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)}]

# %% [markdown]
# # DNN Classifier

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\sgvn252\AppData\Local\Temp\tmpv4_m9zv1
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\sgvn252\\AppData\\Local\\Temp\\tmpv4_m9zv1', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000015C4DCF1F28>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
# UH OH! AN ERROR. Check out the video to see why and how to fix.
# https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-cea30273f6d4> in <module>
#       1 # UH OH! AN ERROR. Check out the video to see why and how to fix.
#       2 # https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
# ----> 3 dnn_model.train(input_fn=input_func,steps=1000)
#
# c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     368
#     369       saving_listeners = _check_listeners_type(saving_listeners)
# --> 370       loss = self._train_model(input_fn, hooks, saving_listeners)
#     371       logging.info('Loss for final step: %s.', loss)
#     372       return self
#
# c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1159       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1160     else:
# -> 1161       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1162
#    1163   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1189       worker_hooks.extend(input_hooks)
#    1190       estimator_spec = self._call_model_fn(
# -> 1191           features, labels, ModeKeys.TRAIN, self.config)
#    1192       global_step_tensor = training_util.get_global_step(g)
#    1193       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#
# c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_estimator\python\estimator\estimator.py in _call_model_fn(self, features, labels, mode, config)
#    1147
#    1148     logging.info('Calling model_fn.')
# -> 1149     model_fn_results = self._model_fn(features=features, **kwargs)
#    1150     logging.info('Done calling model_fn.')
#    1151
#
# c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in _model_fn(features, labels, mode, config)
#     809           input_layer_partitioner=input_layer_partitioner,
#     810           config=config,
# --> 811           batch_norm=batch_norm)
#     812
#     813     super(DNNClassifier, self).__init__(
#
# c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in _dnn_model_fn(features, labels, mode, head, hidden_units, feature_columns, optimizer, activation_fn, dropout, input_layer_partitioner, config, use_tpu, batch_norm)
#     461         input_layer_partitioner=input_layer_partitioner,
#     462         batch_norm=batch_norm)
# --> 463     logits = logit_fn(features=features, mode=mode)
#     464
#     465     return _get_dnn_estimator_spec(use_tpu, head, features, labels, mode,
#
# c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in dnn_logit_fn(features, mode)
#     106         input_layer_partitioner,
#     107         batch_norm,
# --> 108         name='dnn')
#     109     return dnn_model(features, mode)
#     110
#
# c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_estimator\python\estimator\canned\dnn.py in __init__(self, units, hidden_units, feature_columns, activation_fn, dropout, input_layer_partitioner, batch_norm, name, **kwargs)
#     184     if feature_column_lib.is_feature_column_v2(feature_columns):
#     185       self._input_layer = dense_features.DenseFeatures(
# --> 186           feature_columns=feature_columns, name='input_layer')
#     187     else:
#     188       self._input_layer = feature_column.InputLayer(
#
# c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_core\python\feature_column\dense_features.py in __init__(self, feature_columns, trainable, name, **kwargs)
#      84         name=name,
#      85         expected_column_type=fc.DenseColumn,
# ---> 86         **kwargs)
#      87
#      88   @property
#
# c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_core\python\feature_column\feature_column_v2.py in __init__(self, feature_columns, expected_column_type, trainable, name, **kwargs)
#     378             'You can wrap a categorical column with an '
#     379             'embedding_column or indicator_column. Given: {}'.format(
# --> 380                 expected_column_type, column))
#     381
#     382   def build(self, _):
#
# ValueError: Items of feature_columns must be a <class 'tensorflow.python.feature_column.feature_column_v2.DenseColumn'>. You can wrap a categorical column with an embedding_column or indicator_column. Given: VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
embedded_group_column = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,embedded_group_column, age_buckets]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\sgvn252\AppData\Local\Temp\tmp7ddba2ff
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\sgvn252\\AppData\\Local\\Temp\\tmp7ddba2ff', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000015C4DE89390>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_core\python\feature_column\feature_column_v2.py:3079: VocabularyListCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From c:\users\sgvn252\.conda\envs\tensorflow 1\lib\site-packages\tensorflow_core\python\training\adagrad.py:76: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\sgvn252\AppData\Local\Temp\tmp7ddba2ff\model.ckpt.
# INFO:tensorflow:loss = 6.7760043, step = 1
# INFO:tensorflow:global_step/sec: 347.921
# INFO:tensorflow:loss = 4.585629, step = 101 (0.287 sec)
# INFO:tensorflow:global_step/sec: 620.362
# INFO:tensorflow:loss = 8.192158, step = 201 (0.163 sec)
# INFO:tensorflow:global_step/sec: 549.838
# INFO:tensorflow:loss = 9.09166, step = 301 (0.182 sec)
# INFO:tensorflow:global_step/sec: 562.192
# INFO:tensorflow:loss = 4.7567196, step = 401 (0.180 sec)
# INFO:tensorflow:global_step/sec: 575.117
# INFO:tensorflow:loss = 4.039084, step = 501 (0.175 sec)
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 524 vs previous value: 524. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# INFO:tensorflow:global_step/sec: 508.813
# INFO:tensorflow:loss = 4.040767, step = 601 (0.195 sec)
# INFO:tensorflow:global_step/sec: 606.854
# INFO:tensorflow:loss = 6.513581, step = 701 (0.161 sec)
# INFO:tensorflow:global_step/sec: 592.748
# INFO:tensorflow:loss = 4.258799, step = 801 (0.169 sec)
# INFO:tensorflow:global_step/sec: 607.326
# INFO:tensorflow:loss = 5.918848, step = 901 (0.165 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\sgvn252\AppData\Local\Temp\tmp7ddba2ff\model.ckpt.
# INFO:tensorflow:Loss for final step: 3.2301598.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-11-05T16:25:27Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\sgvn252\AppData\Local\Temp\tmp7ddba2ff\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2020-11-05-16:25:28
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.7401575, accuracy_baseline = 0.65748036, auc = 0.81357974, auc_precision_recall = 0.6646264, average_loss = 0.5110348, global_step = 1000, label/mean = 0.34251967, loss = 4.992417, precision = 0.6105263, prediction/mean = 0.38638175, recall = 0.6666667
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\sgvn252\AppData\Local\Temp\tmp7ddba2ff\model.ckpt-1000
# {'accuracy': 0.7401575,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.81357974,
#  'auc_precision_recall': 0.6646264,
#  'average_loss': 0.5110348,
#  'label/mean': 0.34251967,
#  'loss': 4.992417,
#  'precision': 0.6105263,
#  'prediction/mean': 0.38638175,
#  'recall': 0.6666667,
#  'global_step': 1000}

# %% [markdown]
# # Great Job!
